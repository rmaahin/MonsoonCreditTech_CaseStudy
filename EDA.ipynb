# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('preprocessed_data.csv')
df.head()
# Out:
#          Unique_ID  C1  C2  C3  C4  C5     C6  C7    C8     N1  ...      N19  \
# 0  Candidate_48134   1   4   2  66   2  False   1  True  11.05  ...  25856.0
# 1  Candidate_51717   1   0  19   2   0  False   0  True  29.00  ...  11041.3
# 2  Candidate_26401   1   1  16  47   1  False   4  True  17.99  ...   1006.0
# 3  Candidate_34872   1   1  13   1   1   True   6  True  27.50  ...   3398.0
# 4  Candidate_29660   1   0  30  13   2  False   2  True  13.50  ...   4110.0
#
#     N20   N21  N22   N23           N24    N33     N34   N35  \
# 0  17.0  0.88  1.0  40.0  10833.333330  160.0  262.10  17.0
# 1  21.8  0.90  0.9  20.0   6250.000000   24.0   50.29  18.0
# 2   6.0  1.00  0.0  26.0   2413.666667   70.0  126.52  27.0
# 3  31.0  0.96  0.0  44.0   7666.666667  100.0  205.47  21.0
# 4  11.0  0.90  2.0  48.0   4250.000000  150.0  254.51  13.0
#
#    Dependent_Variable
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   0
# ...

# %% [markdown]
# ## Correlation between different variables

# %%
cmap= sns.cubehelix_palette()
plt.figure(figsize=(30,30))
sns.heatmap(df[df.columns[1:len(df.columns)-1]].corr(),cbar=True,annot=True,cmap=cmap, linecolor='black')
plt.savefig('correlation.png')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32276 entries, 0 to 32275
# Data columns (total 37 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unique_ID           32276 non-null  object
#  1   C1                  32276 non-null  int64
#  2   C2                  32276 non-null  int64
#  3   C3                  32276 non-null  int64
#  4   C4                  32276 non-null  int64
#  5   C5                  32276 non-null  int64
#  6   C6                  32276 non-null  bool
#  7   C7                  32276 non-null  int64
#  8   C8                  32276 non-null  bool
#  9   N1                  32276 non-null  float64
#  10  N2                  32276 non-null  float64
#  11  N3                  32276 non-null  float64
#  12  N4                  32276 non-null  float64
#  13  N5                  32276 non-null  float64
#  14  N6                  32276 non-null  float64
# ...

# %%
df.describe(include='all')
# Out:
#               Unique_ID            C1            C2            C3  \
# count             32276  32276.000000  32276.000000  32276.000000
# unique            32276           NaN           NaN           NaN
# top     Candidate_48134           NaN           NaN           NaN
# freq                  1           NaN           NaN           NaN
# mean                NaN      1.122692      2.460869     13.073491
# std                 NaN      0.403706      3.418787     12.000010
# min                 NaN      1.000000      0.000000      0.000000
# 25%                 NaN      1.000000      0.000000      2.000000
# 50%                 NaN      1.000000      1.000000     10.000000
# 75%                 NaN      1.000000      3.000000     20.000000
# max                 NaN      3.000000     20.000000     51.000000
#
#                   C4            C5     C6            C7     C8            N1  \
# count   32276.000000  32276.000000  32276  32276.000000  32276  32276.000000
# ...

# %%
df[df.columns[9:15]].boxplot(figsize=(30, 30))
# Out:
# <AxesSubplot:>

# %%
df[df.columns[15:21]].boxplot(figsize=(30, 30))
# Out:
# <AxesSubplot:>

# %%
df[df.columns[21:27]].boxplot(figsize=(30, 30))
# Out:
# <AxesSubplot:>

# %%
df[df.columns[27:]].boxplot(figsize=(30, 30))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Boxplots for each category in the dependent variable

# %%
sns.boxplot(x='Dependent_Variable', y='N2', data=df)
# Out:
# <AxesSubplot:xlabel='Dependent_Variable', ylabel='N2'>
